# %% [markdown]
# # 05. Training Tree model

# %% [markdown]
# #### This notebook trains an Tree model to predict Gurobi runtime based on structural features and param_id.
# It supports:
# - One-hot encoding for `param_id`
# - Train/Val/Test split

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import torch
import sys
import os
import matplotlib.pyplot as plt
from torch.utils.data import random_split, DataLoader

# %%
# set up project root path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.tree_models import load_data, train_and_evaluate

# %% [markdown]
# ## Dataset and Training

# %%
OUTPUT_CSV = "../data/processed/modeldataset.csv"
FEATURE_COLS = ["VariablesVari.", "BinariesBina.", "IntegersInte.",
                "ContinuousCont.", "ConstraintsCons.", "Nonz.Nonz."]

X, y = load_data(OUTPUT_CSV, FEATURE_COLS)

# %%
train_and_evaluate(X, y, model_type="xgb")
# Out:
#  Model: XGB
#   MAE : 29.67 seconds
#   R²  : -0.0005
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)
